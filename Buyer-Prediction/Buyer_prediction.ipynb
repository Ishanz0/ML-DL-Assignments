# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('Train.csv')
train_df.head()
# Out:
#                          session_id  session_number  \
# 0  57f879e70d3c5fc2a98102d64c9fd84e             715
# 1  a5442b0c7c33d0a811e7661e556b2de8              55
# 2  305cb1486ed8610c00b37007926cb2c4              11
# 3  f2c1ecc9993f0071df91ba178450498c            2794
# 4  e460830ae295e55d2216ebdc761ab9a6            3674
#
#                                         client_agent      device_details  \
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...    Desktop - Chrome
# 1                           Product/8.0 iPhone/8.1.3        iPhone - iOS
# 2  Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like ...  iPhone - MobileWeb
# 3  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...        Desktop - IE
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_1 like ...        iPhone - Web
#
#          date  purchased  added_in_cart  checked_out  time_spent
# 0  2020-01-22          1              0            0     236.886
# 1  2020-02-27          1              0            0    1277.455
# 2  2019-08-01          0              0            0      21.704
# 3  2019-12-30          0              1            0     455.201
# 4  2019-09-10          0              0            0    1164.877

# %%
test_df = pd.read_csv('Test.csv')
test_df.head()
# Out:
#                          session_id  session_number  \
# 0  0bf72b05b2cf70dc5e28c3c09f9c4f97              99
# 1  6bc696d99954e4f1367e845465186aef             935
# 2  3d8611a5ea0f621d205b67f09f663a89             902
# 3  a0351545c032fd0da36289410c6c3354            3223
# 4  dd8999772b0ab27225fb05e5df2f1da6             231
#
#                                         client_agent           device_details  \
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....             Desktop - IE
# 1  Product/160393 Android/4.3 Device/samsung_GT-I...  Android Phone - Android
# 2                         Product/4.2.2 iPhone/7.1.2             iPhone - iOS
# 3  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...             Desktop - IE
# 4  Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKi...         Desktop - Chrome
#
#          date  purchased  added_in_cart  checked_out
# 0  2020-01-07          1              0            0
# 1  2020-02-13          0              0            0
# 2  2019-10-14          1              0            0
# 3  2020-01-26          0              0            0
# 4  2020-01-29          0              0            0

# %%
train = train_df.copy()
test = test_df.copy()

# %%
train = train.drop(labels=['session_id','client_agent'],axis = 1)
test = test.drop(labels=['session_id','client_agent'],axis = 1)

# %%
train['device_details'].value_counts()
# Out:
# iPhone - iOS                  1515
# Desktop - Chrome               815
# iPhone - Web                   665
# Android Phone - Android        326
# Desktop - Safari               313
# Desktop - IE                   292
# iPad - Web                     289
# iPhone - MobileWeb             277
# Desktop - Firefox              234
# Android Tablet - Web           203
# Other - Other                  185
# Unknown - MobileWeb             87
# Android Phone - Web             86
# iPad - iOS                      77
# Android Phone - MobileWeb       54
# Android Tablet - Android         9
# Android Tablet - MobileWeb       2
# Name: device_details, dtype: int64

# %%
train.describe()
# Out:
#        session_number    purchased  added_in_cart  checked_out    time_spent
# count     5429.000000  5429.000000    5429.000000  5429.000000   5429.000000
# mean      1072.835329     0.159145       0.162092     0.017499    663.194292
# std       1436.351474     0.365845       0.368570     0.131132   1713.671664
# min         11.000000     0.000000       0.000000     0.000000     14.400000
# 25%        121.000000     0.000000       0.000000     0.000000     22.699000
# 50%        517.000000     0.000000       0.000000     0.000000     98.312000
# 75%       1397.000000     0.000000       0.000000     0.000000    600.463000
# max       7722.000000     1.000000       1.000000     1.000000  38494.025000

# %%
train["date"] = pd.to_datetime(train['date'])
test["date"] = pd.to_datetime(test['date'])

train["year"] = train['date'].dt.year
test["year"] = test['date'].dt.year

train["month"] = train['date'].dt.month
test["month"] = test['date'].dt.month

train['day']= train['date'].dt.day
test["day"] = test['date'].dt.day

train['diff_date'] = ((train['date'] - pd.datetime(1970,1,1)).dt.total_seconds())/(10**6)
test['diff_date'] = ((test['date'] - pd.datetime(1970,1,1)).dt.total_seconds())/(10**6)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   del sys.path[0]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.

# %%
train.head()
# Out:
#    session_number      device_details       date  purchased  added_in_cart  \
# 0             715    Desktop - Chrome 2020-01-22          1              0
# 1              55        iPhone - iOS 2020-02-27          1              0
# 2              11  iPhone - MobileWeb 2019-08-01          0              0
# 3            2794        Desktop - IE 2019-12-30          0              1
# 4            3674        iPhone - Web 2019-09-10          0              0
#
#    checked_out  time_spent  year  month  day  diff_date
# 0            0     236.886  2020      1   22  1579.6512
# 1            0    1277.455  2020      2   27  1582.7616
# 2            0      21.704  2019      8    1  1564.6176
# 3            0     455.201  2019     12   30  1577.6640
# 4            0    1164.877  2019      9   10  1568.0736

# %%
l = pd.unique(train["device_details"])
device_encoding = {}
x = 0
for i in l:
    if i not in device_encoding:
        device_encoding[i] = x
        x+=1
print(device_encoding)

train["device_encoding"] = train["device_details"].map(device_encoding)
test["device_encoding"] = test["device_details"].map(device_encoding)
# Out:
# {'Desktop - Chrome': 0, 'iPhone - iOS': 1, 'iPhone - MobileWeb': 2, 'Desktop - IE': 3, 'iPhone - Web': 4, 'Android Phone - Android': 5, 'Desktop - Firefox': 6, 'Android Tablet - Web': 7, 'iPad - Web': 8, 'Other - Other': 9, 'Desktop - Safari': 10, 'Android Phone - Web': 11, 'iPad - iOS': 12, 'Android Phone - MobileWeb': 13, 'Unknown - MobileWeb': 14, 'Android Tablet - Android': 15, 'Android Tablet - MobileWeb': 16}

# %%
train.head()
# Out:
#    session_number      device_details       date  purchased  added_in_cart  \
# 0             715    Desktop - Chrome 2020-01-22          1              0
# 1              55        iPhone - iOS 2020-02-27          1              0
# 2              11  iPhone - MobileWeb 2019-08-01          0              0
# 3            2794        Desktop - IE 2019-12-30          0              1
# 4            3674        iPhone - Web 2019-09-10          0              0
#
#    checked_out  time_spent  year  month  day  diff_date  device_encoding
# 0            0     236.886  2020      1   22  1579.6512                0
# 1            0    1277.455  2020      2   27  1582.7616                1
# 2            0      21.704  2019      8    1  1564.6176                2
# 3            0     455.201  2019     12   30  1577.6640                3
# 4            0    1164.877  2019      9   10  1568.0736                4

# %%
cols = ['session_number','device_encoding','purchased','added_in_cart','checked_out','year','month','day','diff_date']
X = train[cols]
Y = train["time_spent"]

# %%
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.model_selection import GridSearchCV,KFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder , OneHotEncoder 
from sklearn.metrics import mean_squared_log_error

import xgboost as xgb

# %%
x_tr,x_tst,y_tr,y_tst = train_test_split(X,Y,test_size=0.3,random_state=6969)

# %%
xgr = xgb.XGBRegressor(booster='gbtree',n_estimators=200)
xgr.fit(X=x_tr[cols],y=y_tr,eval_set=[(x_tr[cols],y_tr)],eval_metric="rmse",verbose=1)
ans = abs(xgr.predict(x_tst))
score = np.sqrt(mean_squared_log_error(y_tst, ans))
score
# Out:
# [08:25:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1837.17
# [1]	validation_0-rmse:1789.44
# [2]	validation_0-rmse:1749.67
# [3]	validation_0-rmse:1716.62
# [4]	validation_0-rmse:1675.05
# [5]	validation_0-rmse:1639.52
# [6]	validation_0-rmse:1609.38
# [7]	validation_0-rmse:1595.84
# [8]	validation_0-rmse:1584.59
# [9]	validation_0-rmse:1569.43
# [10]	validation_0-rmse:1556.96
# [11]	validation_0-rmse:1546.87
# [12]	validation_0-rmse:1525.2
# [13]	validation_0-rmse:1519.73
# [14]	validation_0-rmse:1499.33
# [15]	validation_0-rmse:1492.51
# [16]	validation_0-rmse:1477.39
# [17]	validation_0-rmse:1471.81
# [18]	validation_0-rmse:1462.73
# [19]	validation_0-rmse:1458.27
# [20]	validation_0-rmse:1450.22
# [21]	validation_0-rmse:1438.8
# [22]	validation_0-rmse:1428.79
# [23]	validation_0-rmse:1425.44
# [24]	validation_0-rmse:1419.37
# [25]	validation_0-rmse:1411.03
# [26]	validation_0-rmse:1405.98
# [27]	validation_0-rmse:1392.52
# [28]	validation_0-rmse:1380.65
# [29]	validation_0-rmse:1377.92
# [30]	validation_0-rmse:1373.41
# [31]	validation_0-rmse:1361.43
# [32]	validation_0-rmse:1359.79
# [33]	validation_0-rmse:1350.57
# [34]	validation_0-rmse:1348.21
# [35]	validation_0-rmse:1340.55
# [36]	validation_0-rmse:1337.64
# [37]	validation_0-rmse:1329.98
# [38]	validation_0-rmse:1327.47
# [39]	validation_0-rmse:1325.76
# [40]	validation_0-rmse:1319.21
# [41]	validation_0-rmse:1318.58
# [42]	validation_0-rmse:1317.36
# [43]	validation_0-rmse:1311.78
# [44]	validation_0-rmse:1309.77
# [45]	validation_0-rmse:1307.3
# [46]	validation_0-rmse:1301.73
# [47]	validation_0-rmse:1298.79
# [48]	validation_0-rmse:1293.16
# [49]	validation_0-rmse:1292.66
# [50]	validation_0-rmse:1291.37
# [51]	validation_0-rmse:1290.06
# [52]	validation_0-rmse:1289.65
# [53]	validation_0-rmse:1288.96
# [54]	validation_0-rmse:1288.38
# [55]	validation_0-rmse:1287.1
# [56]	validation_0-rmse:1282.5
# [57]	validation_0-rmse:1280.52
# [58]	validation_0-rmse:1276.51
# [59]	validation_0-rmse:1275.58
# [60]	validation_0-rmse:1274.83
# [61]	validation_0-rmse:1270.45
# [62]	validation_0-rmse:1268.28
# [63]	validation_0-rmse:1267.77
# [64]	validation_0-rmse:1265.6
# [65]	validation_0-rmse:1263.01
# [66]	validation_0-rmse:1262.27
# [67]	validation_0-rmse:1261.78
# [68]	validation_0-rmse:1261.33
# [69]	validation_0-rmse:1257.12
# [70]	validation_0-rmse:1256.72
# [71]	validation_0-rmse:1256.07
# [72]	validation_0-rmse:1255.63
# [73]	validation_0-rmse:1254.9
# [74]	validation_0-rmse:1252.51
# [75]	validation_0-rmse:1248.78
# [76]	validation_0-rmse:1246.09
# [77]	validation_0-rmse:1242.75
# [78]	validation_0-rmse:1240.14
# [79]	validation_0-rmse:1237.53
# [80]	validation_0-rmse:1235.83
# [81]	validation_0-rmse:1234.69
# [82]	validation_0-rmse:1230.87
# [83]	validation_0-rmse:1230.14
# [84]	validation_0-rmse:1228.32
# [85]	validation_0-rmse:1227.62
# [86]	validation_0-rmse:1224.86
# [87]	validation_0-rmse:1217.38
# [88]	validation_0-rmse:1216.91
# [89]	validation_0-rmse:1216.51
# [90]	validation_0-rmse:1214.03
# [91]	validation_0-rmse:1211.56
# [92]	validation_0-rmse:1209.86
# [93]	validation_0-rmse:1208.69
# [94]	validation_0-rmse:1208.13
# [95]	validation_0-rmse:1207.78
# [96]	validation_0-rmse:1206.3
# [97]	validation_0-rmse:1199.73
# [98]	validation_0-rmse:1197.84
# [99]	validation_0-rmse:1197.43
# [100]	validation_0-rmse:1195.2
# [101]	validation_0-rmse:1192.52
# [102]	validation_0-rmse:1190.62
# [103]	validation_0-rmse:1184.85
# [104]	validation_0-rmse:1182.86
# [105]	validation_0-rmse:1177.67
# [106]	validation_0-rmse:1175.36
# [107]	validation_0-rmse:1174.99
# [108]	validation_0-rmse:1174
# [109]	validation_0-rmse:1173.18
# [110]	validation_0-rmse:1172.58
# [111]	validation_0-rmse:1172.21
# [112]	validation_0-rmse:1170.67
# [113]	validation_0-rmse:1169.2
# [114]	validation_0-rmse:1167.1
# [115]	validation_0-rmse:1166.76
# [116]	validation_0-rmse:1164.78
# [117]	validation_0-rmse:1164.47
# [118]	validation_0-rmse:1162.48
# [119]	validation_0-rmse:1161.85
# [120]	validation_0-rmse:1160.32
# [121]	validation_0-rmse:1160.02
# [122]	validation_0-rmse:1158.41
# [123]	validation_0-rmse:1156.84
# [124]	validation_0-rmse:1155.64
# [125]	validation_0-rmse:1154.85
# [126]	validation_0-rmse:1153.54
# [127]	validation_0-rmse:1152.93
# [128]	validation_0-rmse:1152.04
# [129]	validation_0-rmse:1151.4
# [130]	validation_0-rmse:1151.13
# [131]	validation_0-rmse:1146.57
# [132]	validation_0-rmse:1146.3
# [133]	validation_0-rmse:1145.14
# [134]	validation_0-rmse:1144.56
# [135]	validation_0-rmse:1143.01
# [136]	validation_0-rmse:1142.14
# [137]	validation_0-rmse:1141.9
# [138]	validation_0-rmse:1136.76
# [139]	validation_0-rmse:1134.99
# [140]	validation_0-rmse:1134.54
# [141]	validation_0-rmse:1133.68
# [142]	validation_0-rmse:1133.35
# [143]	validation_0-rmse:1132.24
# [144]	validation_0-rmse:1131.25
# [145]	validation_0-rmse:1130.28
# [146]	validation_0-rmse:1128.74
# [147]	validation_0-rmse:1125.27
# [148]	validation_0-rmse:1124.45
# [149]	validation_0-rmse:1123.04
# [150]	validation_0-rmse:1121.93
# [151]	validation_0-rmse:1121.69
# [152]	validation_0-rmse:1120.18
# [153]	validation_0-rmse:1116.08
# [154]	validation_0-rmse:1115.01
# [155]	validation_0-rmse:1113.26
# [156]	validation_0-rmse:1108.23
# [157]	validation_0-rmse:1107.31
# [158]	validation_0-rmse:1106.33
# [159]	validation_0-rmse:1101.74
# [160]	validation_0-rmse:1100.88
# [161]	validation_0-rmse:1100.5
# [162]	validation_0-rmse:1099.67
# [163]	validation_0-rmse:1099.21
# [164]	validation_0-rmse:1098.65
# [165]	validation_0-rmse:1098.32
# [166]	validation_0-rmse:1097.98
# [167]	validation_0-rmse:1097
# [168]	validation_0-rmse:1096.39
# [169]	validation_0-rmse:1096.11
# [170]	validation_0-rmse:1095.84
# [171]	validation_0-rmse:1092.68
# [172]	validation_0-rmse:1091.83
# [173]	validation_0-rmse:1091.1
# [174]	validation_0-rmse:1090.52
# [175]	validation_0-rmse:1089.84
# [176]	validation_0-rmse:1089.51
# [177]	validation_0-rmse:1088.41
# [178]	validation_0-rmse:1087.77
# [179]	validation_0-rmse:1087.04
# [180]	validation_0-rmse:1086
# [181]	validation_0-rmse:1085.45
# [182]	validation_0-rmse:1084.95
# [183]	validation_0-rmse:1083.47
# [184]	validation_0-rmse:1083.02
# [185]	validation_0-rmse:1082.4
# [186]	validation_0-rmse:1081.52
# [187]	validation_0-rmse:1078.72
# [188]	validation_0-rmse:1078.39
# [189]	validation_0-rmse:1074.67
# [190]	validation_0-rmse:1074.11
# [191]	validation_0-rmse:1073.87
# [192]	validation_0-rmse:1073.1
# [193]	validation_0-rmse:1069.64
# [194]	validation_0-rmse:1068
# [195]	validation_0-rmse:1065.59
# [196]	validation_0-rmse:1065.53
# [197]	validation_0-rmse:1064.82
# [198]	validation_0-rmse:1064.14
# [199]	validation_0-rmse:1061.16
# 1.8641170477140887

# %%
train.corr().time_spent
# Out:
# session_number     0.078437
# purchased          0.200762
# added_in_cart      0.209807
# checked_out        0.157765
# time_spent         1.000000
# year              -0.030843
# month              0.013367
# day               -0.030206
# diff_date         -0.046154
# device_encoding   -0.020000
# Name: time_spent, dtype: float64

# %%
feat_importances = pd.Series(xgr.feature_importances_, index=cols)
feat_importances.nlargest(6).plot(kind='barh')
plt.show()

# %%
cols = ['session_number','purchased','added_in_cart','checked_out']

# %%
xgr.fit(X=X[cols],y=Y,verbose=2)
ans = xgr.predict(test[cols])
# Out:
# [08:26:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
sub = pd.read_csv('Sample Submission.csv')
sub["time_spent"]=abs(ans)

sub.to_csv('res1.csv', index=False)
